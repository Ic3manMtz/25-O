# %% [markdown]
# # Bibliotecas

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

#Arboles de decision
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
# SVM
from sklearn import svm
# MLP
from sklearn.neural_network import MLPClassifier

from sklearn import metrics

# Para leer y manejar datos
import pandas as pd

# %% [markdown]
# # Carga Datos

# %%
iris = pd.read_csv('iris.csv')
iris.head(5)
# Out:
#    sepallength  sepalwidth  petallength  petalwidth  class
# 0          5.1         3.5          1.4         0.2      0
# 1          4.9         3.0          1.4         0.2      0
# 2          4.7         3.2          1.3         0.2      0
# 3          4.6         3.1          1.5         0.2      0
# 4          5.0         3.6          1.4         0.2      0

# %% [markdown]
# # Divide datos de entrenamiento y de prueba

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.drop('class',axis=1), iris['class'], test_size=0.3)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((105, 4), (45, 4), (105,), (45,))

# %% [markdown]
# ## Clasifica con un árbol de decisión

# %%
# Crea el modelo 
arbol = DecisionTreeClassifier(criterion='entropy')

# Ajusta con los datos 
arbol.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# ### Prueba de funcionamiento

# %%
y_apred = arbol.predict(X_test)

# Precisión del modelo
print("Precisión del modelo de árbol de decisión:", metrics.accuracy_score(y_test, y_apred))

print(iris.columns)
metrics.confusion_matrix(y_test, y_apred)
# Out:
# Precisión del modelo de árbol de decisión: 0.9777777777777777
# Index(['sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'class'], dtype='object')
# array([[19,  0,  0],
#        [ 0,  8,  1],
#        [ 0,  0, 17]])

# %%
plot_tree(arbol)
# Out:
# [Text(0.4444444444444444, 0.9166666666666666, 'x[3] <= 0.8\nentropy = 1.574\nsamples = 105\nvalue = [31, 41, 33]'),
#  Text(0.3333333333333333, 0.75, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0, 0]'),
#  Text(0.38888888888888884, 0.8333333333333333, 'True  '),
#  Text(0.5555555555555556, 0.75, 'x[3] <= 1.75\nentropy = 0.992\nsamples = 74\nvalue = [0, 41, 33]'),
#  Text(0.5, 0.8333333333333333, '  False'),
#  Text(0.4444444444444444, 0.5833333333333334, 'x[2] <= 4.95\nentropy = 0.496\nsamples = 46\nvalue = [0, 41, 5]'),
#  Text(0.2222222222222222, 0.4166666666666667, 'x[3] <= 1.65\nentropy = 0.169\nsamples = 40\nvalue = [0, 39, 1]'),
#  Text(0.1111111111111111, 0.25, 'entropy = 0.0\nsamples = 39\nvalue = [0, 39, 0]'),
#  Text(0.3333333333333333, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6666666666666666, 0.4166666666666667, 'x[3] <= 1.55\nentropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.5555555555555556, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.7777777777777778, 0.25, 'x[2] <= 5.45\nentropy = 0.918\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.6666666666666666, 0.08333333333333333, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8888888888888888, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6666666666666666, 0.5833333333333334, 'entropy = 0.0\nsamples = 28\nvalue = [0, 0, 28]')]

# %% [markdown]
# ## Clasifica con máquinas de soporte vectorial

# %%
# Crea el modelo
svm = svm.LinearSVC()

# Ajusta con los datos
svm.fit(X_train, y_train)
# Out:
# LinearSVC()

# %% [markdown]
# ### Prueba de funcionamiento

# %%
y_apred_svm = svm.predict(X_test)

# Precisión del modelo
print("Precisión del modelo SVM:", metrics.accuracy_score(y_test, y_apred_svm))

print(iris.columns)
metrics.confusion_matrix(y_test, y_apred_svm)
# Out:
# Precisión del modelo SVM: 0.9777777777777777
# array([[19,  0,  0],
#        [ 0,  8,  1],
#        [ 0,  0, 17]])

# %% [markdown]
# ## Clasifica con un multilayer perceptron

# %%
# Crea el modelo
mlp = MLPClassifier(hidden_layer_sizes=(10),activation='tanh',max_iter=1000,random_state=7)

# Ajusta con los datos
mlp.fit(X_train, y_train)
# Out:
# c:\Users\molap\Documents\UAM\25-O\Aprendizaje Maquinal\Laboratorio\scikit\.venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(activation='tanh', hidden_layer_sizes=10, max_iter=1000,
#               random_state=7)

# %% [markdown]
# ### Prueba de funcionamiento

# %%
y_apred_mlp = mlp.predict(X_test)

# Precisión del modelo
print("Precisión del modelo MLP:", metrics.accuracy_score(y_test, y_apred_mlp))

print(iris.columns)
metrics.confusion_matrix(y_test, y_apred_mlp)
# Out:
# Precisión del modelo MLP: 0.9777777777777777
# Index(['sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'class'], dtype='object')
# array([[19,  0,  0],
#        [ 0,  8,  1],
#        [ 0,  0, 17]])
